# %%
import sys
sys.path.append("../")
from constants import *
import pandas as pd
import ast
from collections import Counter
import csv
import warnings
import h5py
import stacklineplot
import matplotlib
matplotlib.rcParams['figure.figsize'] = (12.0, 8.0)

# %%
summary = pd.read_csv(DATASET_SUMMARY)#[:1000] # only first 100 elements -> easier to work with
# Out:
# /mnt/home2/dlongo/.conda/envs/mne-2/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3020: DtypeWarning: Columns (16) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
summary.head()
# Out:
#                    file_name   patient_name                       patientcode  \
# 0  lpch/CA0010ED_1-4+.eeghdf  1260, Subject  2ee5afb61608548aaf92673d2ce8ea9b
# 1  lpch/CA8310Y9_1-8+.eeghdf  1241, Subject  1815bcdb98275b62b6df98f5794c3156
# 2  lpch/CA83110B_1-3+.eeghdf  1215, Subject  a7e628c2c1085c1f85680c175b20d3f4
# 3  lpch/CA8312DO_1-9+.eeghdf  1258, Subject  7cfe9ced26e35b85bfc2e340efc23f0a
# 4  lpch/CA83132S_1-2+.eeghdf  1446, Subject  06548eef257453abb801755e54a18b75
#
#    gender   birthdate  patient_age_days born_premature  \
# 0    Male  1990-01-01         27.187558        unknown
# 1  Female  1990-01-01       5550.430660        unknown
# 2    Male  1990-01-01       4897.914977        unknown
# 3  Female  1990-01-01        482.541562        unknown
# 4  Female  1990-01-01        764.598542        unknown
#
#    gestatational_age_at_birth_days  bits_per_sample    start_isodatetime  \
# 0                             -1.0               16  1990-01-28 04:30:05
# 1                             -1.0               16  2005-03-13 10:20:09
# 2                             -1.0               16  2003-05-30 21:57:34
# 3                             -1.0               16  1991-04-28 12:59:51
# 4                             -1.0               16  1992-02-04 14:21:54
#
#                    ...                   technician  patient_additional  \
# 0                  ...                          NaN                 NaN
# 1                  ...                          NaN                 NaN
# 2                  ...                          NaN                 NaN
# 3                  ...                          NaN                 NaN
# 4                  ...                          NaN                 NaN
#
#                                          annotations  nk_file_reportkey  \
# 0  [('REC START NEONATE EE', 1.7), ('A1+A2 OFF', ...           CA0010ED
# 1  [('REC START DB EEG', 3.2000000000000002), ('A...           CA8310Y9
# 2  [('REC START IA/DB EEG', 0.90000000000000002),...           CA83110B
# 3  [('REC START DB CAL', 0.0), ('A1+A2 OFF', 0.0)...           CA8312DO
# 4  [('REC START RICH-ALL E', 0.0), ('A1+A2 OFF', ...           CA83132S
#
#                            eegdata_uuid                nk_file_reportkey_uuid  \
# 0  35bd1516-6f12-512f-aeb5-40925f359fd1  eddeed09-371e-5219-b2bb-7843687fbd72
# 1  860140a1-81bb-5581-b819-2ad64adb60fd  330d2110-dd53-5e01-9400-42b45cf20fbe
# 2  4c64b1c0-b19e-5a78-9fde-88282d98d867  1929f45f-a51d-5b84-b06a-35ae09dddae8
# 3  01a790b8-a9b6-53a8-a653-03ad226eac9e  90d09f88-fa76-5759-8dca-e3fdb8d8983e
# 4  5b9fb077-bfac-5251-84cc-ebccd9b73dfa  99506698-b38f-59f5-ba51-e9fc4f3b1752
#
#   studytype        base_file_name file_source  \
# 0       LTM  CA0010ED_1-4+.eeghdf        lpch
# 1       LTM  CA8310Y9_1-8+.eeghdf        lpch
# 2       LTM  CA83110B_1-3+.eeghdf        lpch
# 3       LTM  CA8312DO_1-9+.eeghdf        lpch
# 4       LTM  CA83132S_1-2+.eeghdf        lpch
#
#                            old_file_name
# 0  ../lpch/longterm/CA0010ED_1-4+.eeghdf
# 1  ../lpch/longterm/CA8310Y9_1-8+.eeghdf
# 2  ../lpch/longterm/CA83110B_1-3+.eeghdf
# 3  ../lpch/longterm/CA8312DO_1-9+.eeghdf
# 4  ../lpch/longterm/CA83132S_1-2+.eeghdf
#
# [5 rows x 25 columns]

# %%
def save_annotation_counts(counts_list, filename):
    with open(filename, "w") as f:
        out = csv.writer(f)
        out.writerow(['Annotation', 'Count'])
        out.writerows(counts_list)

# %%
def get_annotations(summary, n=200):
    # returns list len = n sorted by most common[(artifact name, count),...]
    annotations_list = []
    for sample in summary["annotations"]:
        cur_samples_list = ast.literal_eval(sample) # must conver sample from string to list
        cur_annotations = [x[0] for x in cur_samples_list]
        annotations_list += cur_annotations
    annotations_cout_dict = Counter(annotations_list)
    return annotations_cout_dict.most_common(n)
    
counts = get_annotations(summary)
save_annotation_counts(counts, "test.csv")

# %%
pd.read_csv("test.csv")#.head()
# Out:
#                Annotation   Count
# 0               A1+A2 OFF  135190
# 1       Spike T3-aT3 1.00   96501
# 2        REC START DB EEG   78228
# 3       Spike T5-aT5 1.00   60840
# 4       Spike T6-aT6 1.00   48748
# 5       Spike T4-aT4 1.00   47551
# 6                 MARK ON   34659
# 7       Spike F3-aF3 1.00   32543
# 8       Spike F7-aF7 1.00   32071
# 9       Spike C4-aC4 1.00   30617
# 10      Spike O1-aO1 1.00   28940
# 11      Spike F4-aF4 1.00   25395
# 12               MARK OFF   25349
# 13      Spike P3-aP3 1.00   24399
# 14      Spike P4-aP4 1.00   23092
# 15    RhythmicBurst F3-F7   21882
# 16      Spike O2-aO2 1.00   21091
# 17            eyes closed   19470
# 18            Eyes Closed   19185
# 19      Spike F8-aF8 1.00   19141
# 20      Spike C3-aC3 1.00   19075
# 21              eyes open   17882
# 22    RhythmicBurst F7-T3   17600
# 23      Spike FZ-aFz 1.00   17415
# 24              Eyes Open   15819
# 25   @SeizureDetected(Per   14527
# 26     REC START A_DB EEG   14395
# 27       REC START SP EEG   14367
# 28                  quiet   13911
# 29          IMP CHECK OFF   13456
# ..                    ...     ...
# 170            PHOTO 25Hz    1559
# 171     Spike T3-aT3 0.95    1534
# 172                 Awake    1534
# 173      Spike X2-X1 0.82    1493
# 174     Spike T3-aT3 0.94    1484
# 175     Spike T3-aT3 0.87    1457
# 176     Spike T3-aT3 0.92    1452
# 177     Spike T3-aT3 0.89    1447
# 178     Spike T5-aT5 0.97    1437
# 179      how do you feel?    1437
# 180                 ?????    1436
# 181               correct    1436
# 182                     X    1426
# 183     Spike T3-aT3 0.82    1400
# 184           good effort    1400
# 185                   EKG    1397
# 186               arousal    1397
# 187     Spike T6-aT6 0.99    1385
# 188     Spike T3-aT3 0.88    1374
# 189     Spike T3-aT3 0.91    1370
# 190     Spike T3-aT3 0.90    1370
# 191     Spike T5-aT5 0.96    1365
# 192            PHOTO 30Hz    1360
# 193         body movement    1342
# 194     Spike T3-aT3 0.93    1341
# 195             DISCHARGE    1336
# 196  REC START Neonatal E    1323
# 197               yawning    1320
# 198     Spike T5-aT5 0.95    1297
# 199     Spike T6-aT6 0.98    1279
#
# [200 rows x 2 columns]

# %%
def check_count_statisfied(target_artifacts, cur_out_artifacts):
    for artifact_name, count in target_artifacts.items():
        if count != len(cur_out_artifacts[artifact_name]):
            # count hasn't yet been reached
            return False
    return True
        

def get_filenames_by_artifacts(target_artifacts):
    '''
     target_artifacts is {artifact name: count, ....}

    returns {artifact name : [(filename, pos), ...], ...}
    '''
    # load summary file
    summary = pd.read_csv(DATASET_SUMMARY)
#     summary = summary.sample(frac=1) # to shuffle
    
    target_artifact_names = list(target_artifacts.keys())
    out_artifacts = {}

    
    # Initial artifacts dict with empty lists
    for artifact_name in target_artifact_names:
        out_artifacts[artifact_name] = []
    
    for _, sample in summary.iterrows():
        
        # Ensure that the counts have not yet been met
        if check_count_statisfied(target_artifacts, out_artifacts):
            return out_artifacts
        
        annotations = sample["annotations"]
        filename = DATASET_PATH + sample["file_name"]
        frequency = sample["sample_frequency"]
        assert(int(frequency) == float(frequency))
        frequency = int(frequency)
        
        annoations_list = ast.literal_eval(annotations)
        
        for annoation in annoations_list:
        
            annoation_name, annoation_time = annoation
            if annoation_name in target_artifact_names:
                
                # Check to ensure the count hasn't yet been satisfied
                if len(out_artifacts[annoation_name]) < target_artifacts[annoation_name]:
                    out_artifacts[annoation_name].append((filename, int(annoation_time * frequency)))
                    
    if not (check_count_statisfied(target_artifacts, out_artifacts)):
        warnings.warn("COUNT NOT MET")
    return out_artifacts

# %%
target_artifacts = {
    "blink" : 220,
#     "yawning" : 5,
#     "PHOTO 30Hz" : 5
}
artifacts = get_filenames_by_artifacts(target_artifacts)

# %% [markdown]
# issue to have lpch and stanford?

# %%
sample_filename, sample_pos = artifacts["blink"][4] # 3

# %%
hdf = h5py.File(sample_filename)

# %%
signals = rec['signals']
labels = rec['signal_labels']
electrode_labels = [str(s,'ascii') for s in labels]
numbered_electrode_labels = ["%d:%s" % (ii, str(labels[ii], 'ascii')) for ii in range(len(labels))]

# %%
stacklineplot.stackplot(signals[:, sample_pos - 84: sample_pos + 700], yscale=3)
