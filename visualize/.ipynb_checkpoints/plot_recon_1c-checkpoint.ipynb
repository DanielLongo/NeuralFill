# %%
import sys 
import stacklineplot
import torch
import torch.utils.data as data
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.rcParams['figure.figsize'] = [18, 10]

# %% [markdown]
# ### Conv VAE

# %%
samples = np.load("../reconstruction/results_recon/eval_recon_1000.npy")
import eegml_signal.filters as esfilters
notch_filter = esfilters.notch_filter_iir_ff(
            notch_freq=60.0, fs=250, Q=60)
notch_filter(samples)
# Out:
# /mnt/home2/dlongo/.conda/envs/mne-2/lib/python3.6/site-packages/scipy/signal/_arraytools.py:45: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   b = a[a_slice]
# array([[0.63974732, 0.6365808 , 0.63205028, ..., 0.64504432, 0.72138232,
#         0.75600004],
#        [0.86906065, 0.94629486, 0.97008738, ..., 0.27648958, 0.4215719 ,
#         0.61071655],
#        [0.46970966, 0.49615369, 0.54154536, ..., 0.9762622 , 0.97099366,
#         0.9700995 ],
#        ...,
#        [0.87458599, 0.87163252, 0.84561154, ..., 0.72875658, 0.71179968,
#         0.71598527],
#        [0.94109815, 0.95597327, 0.95379073, ..., 0.80425582, 0.76732712,
#         0.74398462],
#        [0.35468237, 0.26517055, 0.2036047 , ..., 0.66227269, 0.65293903,
#         0.63169499]])

# %% [markdown]
# #### Original

# %%
stacklineplot.stackplot(notch_filter(samples[:4]))
stacklineplot.stackplot(samples[:4])

# %% [markdown]
# #### Recon

# %%
stacklineplot.stackplot(samples[16:16+4])

# %% [markdown]
# ### Generate Samples

# %%
import torch
import sys
sys.path.append("../")
sys.path.append("../models/")
from VAE1c import VAE1c
from utils import get_gens_samples

# %%
model = torch.load("../reconstruction/saved_models/normal_nn-s_1c_r2")

# %%
samples = get_gens_samples(model, 20)

# %%
stacklineplot.stackplot(samples[:12], yscale=.8)
