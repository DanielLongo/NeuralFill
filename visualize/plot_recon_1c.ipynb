# %%
import sys 
import stacklineplot
import torch
import torch.utils.data as data
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.rcParams['figure.figsize'] = [18, 10]

# %% [markdown]
# ### Most recent VAE

# %%
samples = np.load("../reconstruction/results_recon/sample-train-200.npy")

# %% [markdown]
# #### Generating Blinks & 60hz Noise

# %% [markdown]
# #### Original

# %%
stacklineplot.stackplot(samples[:8], yscale=.8)

# %%
stacklineplot.stackplot(samples[16:16+8], yscale=.8)

# %% [markdown]
# #### Generating with Overlap

# %%
# original
stacklineplot.stackplot(samples[:8], yscale=.8)

# %%
# reconstructed
stacklineplot.stackplot(samples[16:16+8], yscale=.8)

# %% [markdown]
# ### Generated Samples

# %%
import torch
import sys
sys.path.append("../")
sys.path.append("../models/")
from VAE1c import VAE1c
from utils import get_gens_samples

# %% [markdown]
# #### VAE

# %%
model = torch.load("../reconstruction/saved_runs/1593886568/model.pt")

# %%
samples = get_gens_samples(model, 30)

# %%
stacklineplot.stackplot(samples[:12], yscale=.8)

# %% [markdown]
# #### VQ-VAE

# %%
model = torch.load("../reconstruction/saved_runs/1593886455/model.pt")

# %%
samples = get_gens_samples(model, 30)
stacklineplot.stackplot(samples[:12], yscale=.8)
