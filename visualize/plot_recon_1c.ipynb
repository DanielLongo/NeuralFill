# %%
import sys 
import stacklineplot
import torch
import torch.utils.data as data
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.rcParams['figure.figsize'] = [18, 10]

# %% [markdown]
# ### Conv VAE

# %%
samples = np.load("../reconstruction/results_recon/sample-train-199.npy")

# %% [markdown]
# #### Original

# %%
stacklineplot.stackplot(samples[:8], yscale=.8)

# %% [markdown]
# #### Recon

# %%
stacklineplot.stackplot(samples[16:16+8], yscale=.8)

# %% [markdown]
# ### Generated Samples

# %%
import torch
import sys
sys.path.append("../")
sys.path.append("../models/")
from VAE1c import VAE1c
from utils import get_gens_samples

# %%
model = torch.load("../reconstruction/saved_models/normal_nn-s_1c_r5")

# %%
samples = get_gens_samples(model, 20)

# %%
stacklineplot.stackplot(samples[:12], yscale=.8)
