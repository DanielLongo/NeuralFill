# %%
import sys 
import stacklineplot
import torch
import torch.utils.data as data
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [18, 10]

# %% [markdown]
# ### VAE Generations

# %%
def atanh(x):
    return 0.5*torch.log((1+x)/(1-x))

# %%
# samples = np.load("../results/sample_800.npy")
# samples = np.load("../models/vq-vae-2-pytorch/sample.npy")
samples = np.load("../reconstruction/results_recon/eval_vq-vae-2_recon_700.npy")
# samples = np.load("../models/vq-vae-2-pytorch/sample2.npy")
# samples = np.load("../models/vq-vae-2-pytorch/live_testing.npy")

# %%
# samples = atanh(torch.from_numpy((2*samples) - 1))

# %%
stacklineplot.stackplot(samples[:16])

# %%
stacklineplot.stackplot(samples[16:])

# %% [markdown]
# ### Reconstructions

# %%
# samples = np.load("../reconstruction/results_recon/eval_recon_550.npy")
samples = np.load("../models/vq-vae-2-pytorch/sample.npy")

# %% [markdown]
# #### Original

# %%
stacklineplot.stackplot(samples[:16])

# %% [markdown]
# #### Recon

# %%
stacklineplot.stackplot(samples[16:])

# %%
samples.shape
# Out:
# (32, 1024)
