# %%
import sys 
import stacklineplot
import torch
import torch.utils.data as data
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [20, 10]

# %% [markdown]
# ### VAE Generations

# %%
def atanh(x):
    return 0.5*torch.log((1+x)/(1-x))

# %%
samples = np.load("../results/sample_770.npy")

# %%
# samples = atanh(torch.from_numpy((2*samples) - 1))

# %%
stacklineplot.stackplot(samples)

# %% [markdown]
# ### Reconstructions

# %%
samples = np.load("../results/test_recon_44.npy")

# %% [markdown]
# #### Original

# %%
stacklineplot.stackplot(samples[:4])

# %% [markdown]
# #### Recon

# %%
stacklineplot.stackplot(samples[16:16+4])
