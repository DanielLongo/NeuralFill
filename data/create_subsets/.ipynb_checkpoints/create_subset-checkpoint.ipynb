# %%
import eeghdf
import eegvis
import eegvis.stacklineplot
import eegvis.stackplot_bokeh as splotb
import eegvis.nb_eegview as nb_eegview
import edflib  # pyedf is also an option

# %%
from bokeh.io import output_notebook, push_notebook
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (10,8)
output_notebook() # note in ordinary jupyter notebook only need this once, in colab needed for each cell with bokeh
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>

# %%
import pandas as pd
import sys
sys.path.append("../../")
from constants import *

# %%
filenames = pd.read_csv(TRAIN_FILES_CSV).filename
sample = filenames[0]

# %%
hf = eeghdf.Eeghdf(sample)
fig = splotb.show_epoch_centered(hf.phys_signals, 20, epoch_width_sec=10, chstart=0, chstop=19,
                               fs=hf.sample_frequency,ylabels=hf.electrode_labels)

# %%
save_file = "test.csv"

# %%
output_notebook()
# current built in montage derivations: 'trace', 'tcp', double banana', laplacian', neonatal', 'DB-REF'
eegplot = nb_eegview.EeghdfBrowser(eeghdf_file=sample, save_file=save_file, montage='double banana', yscale=3.0)
eegplot.loc_sec = 50
eegplot.show()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1129">Loading BokehJS ...</span>
#     </div>
# HBox(children=(Dropdown(description='Montage:', index=2, layout=Layout(width='15em'), options=('trace', 'tcp',…
#   <div class="bk-root" id="aa78fa6d-ad07-4a08-8f58-9021d91a4a9d" data-root-id="1130"></div>
# HBox(children=(Button(description='go backward 10s', style=ButtonStyle()), Button(description='go forward 10s'…

# %%
pd.read_csv(save_file)
# Out:
#                                             filename    loc
# 0    <eeghdf.reader.Eeghdf object at 0x7fc66c4aef90>  10400
# 1  /mnt/data1/eegdbs/SEC-0.1/stanford/DA00338H_1-...  10000
# 2  /mnt/data1/eegdbs/SEC-0.1/stanford/DA00338H_1-...  13000
